# %% [markdown]
# # <span><h1 style = "font-family: garamond; font-size: 40px; font-style: normal; letter-spcaing: 3px; background-color: #f6f5f5; color :#fe346e; border-radius: 100px 100px; text-align:center">Install Required Libraries</h1></span>

# %%
# !pip install --upgrade wandb
# Out:
# Requirement already satisfied: wandb in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (0.16.6)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from wandb) (3.1.42)
# Requirement already satisfied: requests<3,>=2.0.0 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from wandb) (5.9.0)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from wandb) (1.40.5)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: PyYAML in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from wandb) (6.0)
# Requirement already satisfied: setproctitle in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from wandb) (68.0.0)
# Requirement already satisfied: appdirs>=1.4.3 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from wandb) (4.24.4)
# Requirement already satisfied: six>=1.4.0 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb) (2023.7.22)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (5.0.1)

# %% [markdown]
# # <span><h1 style = "font-family: garamond; font-size: 40px; font-style: normal; letter-spcaing: 3px; background-color: #f6f5f5; color :#fe346e; border-radius: 100px 100px; text-align:center">Import Required Libraries 📚</h1></span>

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (4.38.2)
# Requirement already satisfied: filelock in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from transformers) (0.21.4)
# Requirement already satisfied: numpy>=1.17 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from transformers) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.9.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/narotam21477/miniconda3/envs/prcly/lib/python3.11/site-packages (from requests->transformers) (2023.7.22)

# %%
import os
import gc
import copy
import time
import random
import string

# For data manipulation
import numpy as np
import pandas as pd

# Pytorch Imports
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import Dataset, DataLoader

# Utils
from tqdm import tqdm
from collections import defaultdict

# Sklearn Imports
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import StratifiedKFold, KFold

# For Transformer Models
from transformers import AutoTokenizer, AutoModel, AdamW

# For colored terminal text
# from colorama import Fore, Back, Style
# b_ = Fore.BLUE
# y_ = Fore.YELLOW
# sr_ = Style.RESET_ALL

# Suppress warnings
import warnings
warnings.filterwarnings("ignore")

# For descriptive error messages
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# %% [markdown]
# <img src="https://i.imgur.com/gb6B4ig.png" width="400" alt="Weights & Biases" />
#
# <span style="color: #000508; font-family: Segoe UI; font-size: 1.2em; font-weight: 300;"> Weights & Biases (W&B) is a set of machine learning tools that helps you build better models faster. <strong>Kaggle competitions require fast-paced model development and evaluation</strong>. There are a lot of components: exploring the training data, training different models, combining trained models in different combinations (ensembling), and so on.</span>
#
# > <span style="color: #000508; font-family: Segoe UI; font-size: 1.2em; font-weight: 300;">⏳ Lots of components = Lots of places to go wrong = Lots of time spent debugging</span>
#
# <span style="color: #000508; font-family: Segoe UI; font-size: 1.2em; font-weight: 300;">W&B can be useful for Kaggle competition with it's lightweight and interoperable tools:</span>
#
# * <span style="color: #000508; font-family: Segoe UI; font-size: 1.2em; font-weight: 300;">Quickly track experiments,<br></span>
# * <span style="color: #000508; font-family: Segoe UI; font-size: 1.2em; font-weight: 300;">Version and iterate on datasets, <br></span>
# * <span style="color: #000508; font-family: Segoe UI; font-size: 1.2em; font-weight: 300;">Evaluate model performance,<br></span>
# * <span style="color: #000508; font-family: Segoe UI; font-size: 1.2em; font-weight: 300;">Reproduce models,<br></span>
# * <span style="color: #000508; font-family: Segoe UI; font-size: 1.2em; font-weight: 300;">Visualize results and spot regressions,<br></span>
# * <span style="color: #000508; font-family: Segoe UI; font-size: 1.2em; font-weight: 300;">Share findings with colleagues.</span>
#
# <span style="color: #000508; font-family: Segoe UI; font-size: 1.2em; font-weight: 300;">To learn more about Weights and Biases check out this <strong><a href="https://www.kaggle.com/ayuraj/experiment-tracking-with-weights-and-biases">kernel</a></strong>.</span>

# %%
import wandb

try:    
    wandb.login(key="3b35d1d20a61e201f1d0a77448c48771b233d70c")
    os.environ["WANDB_API_KEY"] = "3b35d1d20a61e201f1d0a77448c48771b233d70c"
    anony = None
except:
    anony = "must"
    print('If you want to use your W&B account, go to Add-ons -> Secrets and provide your W&B access token. Use the Label name as wandb_api. \nGet your W&B access token from here: https://wandb.ai/authorize')
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: kayfake. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /home/narotam21477/.netrc

# %% [markdown]
# # <span><h1 style = "font-family: garamond; font-size: 40px; font-style: normal; letter-spcaing: 3px; background-color: #f6f5f5; color :#fe346e; border-radius: 100px 100px; text-align:center">Training Configuration ⚙️</h1></span>

# %%
def id_generator(size=12, chars=string.ascii_lowercase + string.digits):
    return ''.join(random.SystemRandom().choice(chars) for _ in range(size))

HASH_NAME = id_generator(size=12)
print(HASH_NAME)
# Out:
# g2sx1gpqda82

# %% [markdown]
# <span style="color: #000508; font-family: Segoe UI; font-size: 1.2em; font-weight: 300;">Each experiments are grouped together using the hash-value<br></span>
#
# ![](https://i.imgur.com/Maej42h.jpg)

# %%
CONFIG = {"seed": 2021,
          "epochs": 3,
          "model_name": "roberta-base",
          "train_batch_size": 32,
          "valid_batch_size": 64,
          "max_length": 128,
          "learning_rate": 1e-4,
          "scheduler": 'CosineAnnealingLR',
          "min_lr": 1e-6,
          "T_max": 500,
          "weight_decay": 1e-6,
          "n_fold": 5,
          "n_accumulate": 1,
          "num_classes": 1,
          "margin": 0.5,
          "device": "cpu",
          "hash_name": HASH_NAME
          }

CONFIG["tokenizer"] = AutoTokenizer.from_pretrained(CONFIG['model_name'])
CONFIG['group'] = f'{HASH_NAME}-Baseline'

# %% [markdown]
# # <span><h1 style = "font-family: garamond; font-size: 40px; font-style: normal; letter-spcaing: 3px; background-color: #f6f5f5; color :#fe346e; border-radius: 100px 100px; text-align:center">Set Seed for Reproducibility</h1></span>

# %%
def set_seed(seed=42):
    '''Sets the seed of the entire notebook so results are the same every time we run.
    This is for REPRODUCIBILITY.'''
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    # When running on the CuDNN backend, two further options must be set
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    # Set a fixed value for the hash seed
    os.environ['PYTHONHASHSEED'] = str(seed)
    
set_seed(CONFIG['seed'])

# %% [markdown]
# # <h1 style = "font-family: garamond; font-size: 40px; font-style: normal; letter-spcaing: 3px; background-color: #f6f5f5; color :#fe346e; border-radius: 100px 100px; text-align:center">Read the Data 📖</h1>

# %%
df = pd.read_csv("train.En.csv")
df=df.loc[df['sarcastic'] == 1]
df=df[['tweet','rephrase','sarcastic']]
df.head()
# Out:
#                                                tweet  \
# 0  The only thing I got from college is a caffein...
# 1  I love it when professors draw a big question ...
# 2  Remember the hundred emails from companies whe...
# 3  Today my pop-pop told me I was not “forced” to...
# 4  @VolphanCarol @littlewhitty @mysticalmanatee I...
#
#                                             rephrase  sarcastic
# 0  College is really difficult, expensive, tiring...          1
# 1  I do not like when professors don’t write out ...          1
# 2  I, at the bare minimum, wish companies actuall...          1
# 3  Today my pop-pop told me I was not "forced" to...          1
# 4  I would say Ted Cruz is an asshole and doesn’t...          1

# %%
train, validate, test = \
              np.split(df.sample(frac=1, random_state=42), 
                       [int(.6*len(df)), int(.8*len(df))])

# %%
train=pd.concat([train, validate], ignore_index=True)

# %% [markdown]
# # <span><h1 style = "font-family: garamond; font-size: 40px; font-style: normal; letter-spcaing: 3px; background-color: #f6f5f5; color :#fe346e; border-radius: 100px 100px; text-align:center">Create Folds</h1></span>

# %%
skf = StratifiedKFold(n_splits=CONFIG['n_fold'], shuffle=True, random_state=CONFIG['seed'])

for fold, ( _, val_) in enumerate(skf.split(X=train, y=train.sarcastic)):
    train.loc[val_ , "kfold"] = int(fold)
    
train["kfold"] = train["kfold"].astype(int)
train.head()
# Out:
#                                                tweet  \
# 0  All the shade i have been hearing about Ben Pl...
# 1  you would think the odds of me sitting next to...
# 2  Billy Gunn sorta relevant for the first time i...
# 3  I see Dettol, Toilet Duck and Zoflora are all ...
# 4  @catboychika Aren't you happy I gave you less ...
#
#                                             rephrase  sarcastic  kfold
# 0  Dear Evan Hanson cast the same type of older a...          1      4
# 1  I can't believe the same man ended up sitting ...          1      2
# 2      Billy Gunn is actually in the spotlight now.           1      4
# 3  Donald Trump asked the Chief Medical Officer i...          1      2
# 4     Sorry for putting off the event for so long TT          1      2

# %% [markdown]
# # <span><h1 style = "font-family: garamond; font-size: 40px; font-style: normal; letter-spcaing: 3px; background-color: #f6f5f5; color :#fe346e; border-radius: 100px 100px; text-align:center">Dataset Class</h1></span>

# %%
class JigsawDataset(Dataset):
    def __init__(self, df, tokenizer, max_length):
        self.df = df
        self.max_len = max_length
        self.tokenizer = tokenizer
        self.more_toxic = df['tweet'].values
        self.less_toxic = df['rephrase'].values
        
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, index):
        more_toxic = self.more_toxic[index]
        less_toxic = self.less_toxic[index]
        inputs_more_toxic = self.tokenizer.encode_plus(
                                more_toxic,
                                truncation=True,
                                add_special_tokens=True,
                                max_length=self.max_len,
                                padding='max_length'
                            )
        inputs_less_toxic = self.tokenizer.encode_plus(
                                less_toxic,
                                truncation=True,
                                add_special_tokens=True,
                                max_length=self.max_len,
                                padding='max_length'
                            )
        target = 1
        
        more_toxic_ids = inputs_more_toxic['input_ids']
        more_toxic_mask = inputs_more_toxic['attention_mask']
        
        less_toxic_ids = inputs_less_toxic['input_ids']
        less_toxic_mask = inputs_less_toxic['attention_mask']
        
        
        return {
            'more_toxic_ids': torch.tensor(more_toxic_ids, dtype=torch.long),
            'more_toxic_mask': torch.tensor(more_toxic_mask, dtype=torch.long),
            'less_toxic_ids': torch.tensor(less_toxic_ids, dtype=torch.long),
            'less_toxic_mask': torch.tensor(less_toxic_mask, dtype=torch.long),
            'target': torch.tensor(target, dtype=torch.long)
        }

# %% [markdown]
# # <span><h1 style = "font-family: garamond; font-size: 40px; font-style: normal; letter-spcaing: 3px; background-color: #f6f5f5; color :#fe346e; border-radius: 100px 100px; text-align:center">Create Model</h1></span>

# %%
class JigsawModel(nn.Module):
    def __init__(self, model_name):
        super(JigsawModel, self).__init__()
        self.model = AutoModel.from_pretrained(model_name)
        self.drop = nn.Dropout(p=0.2)
        self.fc = nn.Linear(768, CONFIG['num_classes'])
        
    def forward(self, ids, mask):        
        out = self.model(input_ids=ids,attention_mask=mask,
                         output_hidden_states=False)
        out = self.drop(out[1])
        outputs = self.fc(out)
        return outputs

# %% [markdown]
# # <span><h1 style = "font-family: garamond; font-size: 40px; font-style: normal; letter-spcaing: 3px; background-color: #f6f5f5; color :#fe346e; border-radius: 100px 100px; text-align:center">Loss Function</h1></span>
#
# ![](https://i.imgur.com/qYwVt8V.jpg)
#
# <span style="color: #000508; font-family: Segoe UI; font-size: 1.5em; font-weight: 300;">Check the official documentation <a href="https://pytorch.org/docs/stable/generated/torch.nn.MarginRankingLoss.html">here</a></span>

# %%
def criterion(outputs1, outputs2, targets):
    outputs1 = outputs1.squeeze(dim=1)
    outputs2 = outputs2.squeeze(dim=1)
    return nn.MarginRankingLoss(margin=CONFIG['margin'])(outputs1, outputs2, targets)

# %% [markdown]
# # <span><h1 style = "font-family: garamond; font-size: 40px; font-style: normal; letter-spcaing: 3px; background-color: #f6f5f5; color :#fe346e; border-radius: 100px 100px; text-align:center">Training Function</h1></span>

# %%
def train_one_epoch(model, optimizer, scheduler, dataloader, device, epoch):
    model.train()
    
    dataset_size = 0
    running_loss = 0.0
    
    bar = tqdm(enumerate(dataloader), total=len(dataloader))
    for step, data in bar:
        more_toxic_ids = data['more_toxic_ids'].to(device, dtype = torch.long)
        more_toxic_mask = data['more_toxic_mask'].to(device, dtype = torch.long)
        less_toxic_ids = data['less_toxic_ids'].to(device, dtype = torch.long)
        less_toxic_mask = data['less_toxic_mask'].to(device, dtype = torch.long)
        targets = data['target'].to(device, dtype=torch.long)
        
        batch_size = more_toxic_ids.size(0)

        more_toxic_outputs = model(more_toxic_ids, more_toxic_mask)
        less_toxic_outputs = model(less_toxic_ids, less_toxic_mask)
        
        loss = criterion(more_toxic_outputs, less_toxic_outputs, targets)
        loss = loss / CONFIG['n_accumulate']
        loss.backward()
    
        if (step + 1) % CONFIG['n_accumulate'] == 0:
            optimizer.step()

            # zero the parameter gradients
            optimizer.zero_grad()

            if scheduler is not None:
                scheduler.step()
                
        running_loss += (loss.item() * batch_size)
        dataset_size += batch_size
        
        epoch_loss = running_loss / dataset_size
        
        bar.set_postfix(Epoch=epoch, Train_Loss=epoch_loss,
                        LR=optimizer.param_groups[0]['lr'])
    gc.collect()
    
    return epoch_loss

# %% [markdown]
# # <span><h1 style = "font-family: garamond; font-size: 40px; font-style: normal; letter-spcaing: 3px; background-color: #f6f5f5; color :#fe346e; border-radius: 100px 100px; text-align:center">Validation Function</h1></span>

# %%
@torch.no_grad()
def valid_one_epoch(model, dataloader, device, epoch):
    model.eval()
    
    dataset_size = 0
    running_loss = 0.0
    
    bar = tqdm(enumerate(dataloader), total=len(dataloader))
    for step, data in bar:        
        more_toxic_ids = data['more_toxic_ids'].to(device, dtype = torch.long)
        more_toxic_mask = data['more_toxic_mask'].to(device, dtype = torch.long)
        less_toxic_ids = data['less_toxic_ids'].to(device, dtype = torch.long)
        less_toxic_mask = data['less_toxic_mask'].to(device, dtype = torch.long)
        targets = data['target'].to(device, dtype=torch.long)
        
        batch_size = more_toxic_ids.size(0)

        more_toxic_outputs = model(more_toxic_ids, more_toxic_mask)
        less_toxic_outputs = model(less_toxic_ids, less_toxic_mask)
        
        loss = criterion(more_toxic_outputs, less_toxic_outputs, targets)
        
        running_loss += (loss.item() * batch_size)
        dataset_size += batch_size
        
        epoch_loss = running_loss / dataset_size
        
        bar.set_postfix(Epoch=epoch, Valid_Loss=epoch_loss,
                        LR=optimizer.param_groups[0]['lr'])   
    
    gc.collect()
    
    return epoch_loss

# %% [markdown]
# # <span><h1 style = "font-family: garamond; font-size: 40px; font-style: normal; letter-spcaing: 3px; background-color: #f6f5f5; color :#fe346e; border-radius: 100px 100px; text-align:center">Run Training</h1></span>

# %%
def run_training(model, optimizer, scheduler, device, num_epochs, fold):
    # To automatically log gradients
    wandb.watch(model, log_freq=100)
    
    if torch.cuda.is_available():
        print("[INFO] Using GPU: {}\n".format(torch.cuda.get_device_name()))
    
    start = time.time()
    best_model_wts = copy.deepcopy(model.state_dict())
    best_epoch_loss = np.inf
    history = defaultdict(list)
    
    for epoch in range(1, num_epochs + 1): 
        gc.collect()
        train_epoch_loss = train_one_epoch(model, optimizer, scheduler, 
                                           dataloader=train_loader, 
                                           device=CONFIG['device'], epoch=epoch)
        
        val_epoch_loss = valid_one_epoch(model, valid_loader, device=CONFIG['device'], 
                                         epoch=epoch)
    
        history['Train Loss'].append(train_epoch_loss)
        history['Valid Loss'].append(val_epoch_loss)
        
        # Log the metrics
        wandb.log({"Train Loss": train_epoch_loss})
        wandb.log({"Valid Loss": val_epoch_loss})
        
        # deep copy the model
        if val_epoch_loss <= best_epoch_loss:
            print(f"Validation Loss Improved ({best_epoch_loss} ---> {val_epoch_loss})")
            best_epoch_loss = val_epoch_loss
            run.summary["Best Loss"] = best_epoch_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            PATH = f"/content/drive/MyDrive/ISarcasm/TaskC_models/roberta_model_EN/Loss-Fold-{fold}.bin"
            torch.save(model.state_dict(), "roberta.pth")
            # Save a model file from the current directory
            print(f"Model Saved")
            
        print()
    
    end = time.time()
    time_elapsed = end - start
    print('Training complete in {:.0f}h {:.0f}m {:.0f}s'.format(
        time_elapsed // 3600, (time_elapsed % 3600) // 60, (time_elapsed % 3600) % 60))
    print("Best Loss: {:.4f}".format(best_epoch_loss))
    
    # load best model weights
    model.load_state_dict(best_model_wts)
    
    return model, history

# %%
def prepare_loaders(fold):
    df_train = train[train.kfold != fold].reset_index(drop=True)
    df_valid = train[train.kfold == fold].reset_index(drop=True)
    
    train_dataset = JigsawDataset(df_train, tokenizer=CONFIG['tokenizer'], max_length=CONFIG['max_length'])
    valid_dataset = JigsawDataset(df_valid, tokenizer=CONFIG['tokenizer'], max_length=CONFIG['max_length'])

    train_loader = DataLoader(train_dataset, batch_size=CONFIG['train_batch_size'], 
                              num_workers=2, shuffle=True, pin_memory=True, drop_last=True)
    valid_loader = DataLoader(valid_dataset, batch_size=CONFIG['valid_batch_size'], 
                              num_workers=2, shuffle=False, pin_memory=True)
    
    return train_loader, valid_loader

# %%
def fetch_scheduler(optimizer):
    if CONFIG['scheduler'] == 'CosineAnnealingLR':
        scheduler = lr_scheduler.CosineAnnealingLR(optimizer,T_max=CONFIG['T_max'], 
                                                   eta_min=CONFIG['min_lr'])
    elif CONFIG['scheduler'] == 'CosineAnnealingWarmRestarts':
        scheduler = lr_scheduler.CosineAnnealingWarmRestarts(optimizer,T_0=CONFIG['T_0'], 
                                                             eta_min=CONFIG['min_lr'])
    elif CONFIG['scheduler'] == None:
        return None
        
    return scheduler

# %%
import gc
gc.collect()
# Out:
# 19533

# %% [markdown]
# <span style="color: #000508; font-family: Segoe UI; font-size: 1.5em; font-weight: 300;">Start Training</span>

# %%
for fold in range(0, CONFIG['n_fold']):
    print(f"====== Fold: {fold} ======")
    run = wandb.init(project='Jigsaw', 
                     config=CONFIG,
                     job_type='Train',
                     group=CONFIG['group'],
                     tags=['roberta-base', f'{HASH_NAME}', 'margin-loss'],
                     name=f'{HASH_NAME}-fold-{fold}',
                     anonymous='must')
    
    # Create Dataloaders
    train_loader, valid_loader = prepare_loaders(fold=fold)
    
    model = JigsawModel(CONFIG['model_name'])
    model.to(CONFIG['device'])
    
    # Define Optimizer and Scheduler
    optimizer = AdamW(model.parameters(), lr=CONFIG['learning_rate'], weight_decay=CONFIG['weight_decay'])
    scheduler = fetch_scheduler(optimizer)
    
    model, history = run_training(model, optimizer, scheduler,
                                  device=CONFIG['device'],
                                  num_epochs=CONFIG['epochs'],
                                  fold=fold)
    
    run.finish()
    
    del model, history, train_loader, valid_loader
    _ = gc.collect()
    print()
# Out:
# ====== Fold: 0 ======
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# Finishing last run (ID:w3tcht0h) before initializing another...
# VBox(children=(Label(value='0.007 MB of 0.007 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#  View run <strong style="color:#cdcd00">g2sx1gpqda82-fold-0</strong> at: <a href='https://wandb.ai/kayfake/Jigsaw/runs/w3tcht0h' target="_blank">https://wandb.ai/kayfake/Jigsaw/runs/w3tcht0h</a><br/> View project at: <a href='https://wandb.ai/kayfake/Jigsaw' target="_blank">https://wandb.ai/kayfake/Jigsaw</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240424_232557-w3tcht0h/logs</code>
# Successfully finished last run (ID:w3tcht0h). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011112403704060449, max=1.0…
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/narotam21477/Precily/lux_nlp/Model_1/wandb/run-20240424_233025-0mgjggnd</code>
# Syncing run <strong><a href='https://wandb.ai/kayfake/Jigsaw/runs/0mgjggnd' target="_blank">g2sx1gpqda82-fold-0</a></strong> to <a href='https://wandb.ai/kayfake/Jigsaw' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/kayfake/Jigsaw' target="_blank">https://wandb.ai/kayfake/Jigsaw</a>
#  View run at <a href='https://wandb.ai/kayfake/Jigsaw/runs/0mgjggnd' target="_blank">https://wandb.ai/kayfake/Jigsaw/runs/0mgjggnd</a>
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [INFO] Using GPU: NVIDIA RTX A6000
# 100%|██████████| 17/17 [01:31<00:00,  5.41s/it, Epoch=1, LR=9.97e-5, Train_Loss=0.196]
# 100%|██████████| 3/3 [00:07<00:00,  2.60s/it, Epoch=1, LR=9.97e-5, Valid_Loss=0.0499]
# Validation Loss Improved (inf ---> 0.049930250071149936)
# Model Saved
# 100%|██████████| 17/17 [01:33<00:00,  5.49s/it, Epoch=2, LR=9.89e-5, Train_Loss=0.0452]
# 100%|██████████| 3/3 [00:07<00:00,  2.44s/it, Epoch=2, LR=9.89e-5, Valid_Loss=0.0597]
# 100%|██████████| 17/17 [01:34<00:00,  5.57s/it, Epoch=3, LR=9.75e-5, Train_Loss=0.0232]
# 100%|██████████| 3/3 [00:07<00:00,  2.47s/it, Epoch=3, LR=9.75e-5, Valid_Loss=0.0305]
# Validation Loss Improved (0.049930250071149936 ---> 0.030495029505637053)
# Model Saved
#
# Training complete in 0h 5m 8s
# Best Loss: 0.0305
# VBox(children=(Label(value='0.007 MB of 0.007 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train Loss</td><td>█▂▁</td></tr><tr><td>Valid Loss</td><td>▆█▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Best Loss</td><td>0.0305</td></tr><tr><td>Train Loss</td><td>0.02321</td></tr><tr><td>Valid Loss</td><td>0.0305</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">g2sx1gpqda82-fold-0</strong> at: <a href='https://wandb.ai/kayfake/Jigsaw/runs/0mgjggnd' target="_blank">https://wandb.ai/kayfake/Jigsaw/runs/0mgjggnd</a><br/> View project at: <a href='https://wandb.ai/kayfake/Jigsaw' target="_blank">https://wandb.ai/kayfake/Jigsaw</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240424_233025-0mgjggnd/logs</code>
# ====== Fold: 1 ======
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011112453291813533, max=1.0…
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/narotam21477/Precily/lux_nlp/Model_1/wandb/run-20240424_233554-sbzk4jaz</code>
# Syncing run <strong><a href='https://wandb.ai/kayfake/Jigsaw/runs/sbzk4jaz' target="_blank">g2sx1gpqda82-fold-1</a></strong> to <a href='https://wandb.ai/kayfake/Jigsaw' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/kayfake/Jigsaw' target="_blank">https://wandb.ai/kayfake/Jigsaw</a>
#  View run at <a href='https://wandb.ai/kayfake/Jigsaw/runs/sbzk4jaz' target="_blank">https://wandb.ai/kayfake/Jigsaw/runs/sbzk4jaz</a>
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [INFO] Using GPU: NVIDIA RTX A6000
# 100%|██████████| 17/17 [01:34<00:00,  5.54s/it, Epoch=1, LR=9.97e-5, Train_Loss=0.183]
# 100%|██████████| 3/3 [00:07<00:00,  2.40s/it, Epoch=1, LR=9.97e-5, Valid_Loss=0.0522]
# Validation Loss Improved (inf ---> 0.05219623682310255)
# Model Saved
# 100%|██████████| 17/17 [01:36<00:00,  5.66s/it, Epoch=2, LR=9.89e-5, Train_Loss=0.0492]
# 100%|██████████| 3/3 [00:07<00:00,  2.41s/it, Epoch=2, LR=9.89e-5, Valid_Loss=0.0428]
# Validation Loss Improved (0.05219623682310255 ---> 0.04284942836212597)
# Model Saved
# 100%|██████████| 17/17 [01:33<00:00,  5.48s/it, Epoch=3, LR=9.75e-5, Train_Loss=0.0297]
# 100%|██████████| 3/3 [00:07<00:00,  2.34s/it, Epoch=3, LR=9.75e-5, Valid_Loss=0.0276]
# Validation Loss Improved (0.04284942836212597 ---> 0.027578274551913036)
# Model Saved
#
# Training complete in 0h 5m 14s
# Best Loss: 0.0276
# VBox(children=(Label(value='0.007 MB of 0.007 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train Loss</td><td>█▂▁</td></tr><tr><td>Valid Loss</td><td>█▅▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Best Loss</td><td>0.02758</td></tr><tr><td>Train Loss</td><td>0.02971</td></tr><tr><td>Valid Loss</td><td>0.02758</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">g2sx1gpqda82-fold-1</strong> at: <a href='https://wandb.ai/kayfake/Jigsaw/runs/sbzk4jaz' target="_blank">https://wandb.ai/kayfake/Jigsaw/runs/sbzk4jaz</a><br/> View project at: <a href='https://wandb.ai/kayfake/Jigsaw' target="_blank">https://wandb.ai/kayfake/Jigsaw</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240424_233554-sbzk4jaz/logs</code>
# ====== Fold: 2 ======
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011112181055876944, max=1.0…
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/narotam21477/Precily/lux_nlp/Model_1/wandb/run-20240424_234125-z0sr38yr</code>
# Syncing run <strong><a href='https://wandb.ai/kayfake/Jigsaw/runs/z0sr38yr' target="_blank">g2sx1gpqda82-fold-2</a></strong> to <a href='https://wandb.ai/kayfake/Jigsaw' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/kayfake/Jigsaw' target="_blank">https://wandb.ai/kayfake/Jigsaw</a>
#  View run at <a href='https://wandb.ai/kayfake/Jigsaw/runs/z0sr38yr' target="_blank">https://wandb.ai/kayfake/Jigsaw/runs/z0sr38yr</a>
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [INFO] Using GPU: NVIDIA RTX A6000
# 100%|██████████| 17/17 [01:32<00:00,  5.44s/it, Epoch=1, LR=9.97e-5, Train_Loss=0.192]
# 100%|██████████| 3/3 [00:07<00:00,  2.40s/it, Epoch=1, LR=9.97e-5, Valid_Loss=0.0729]
# Validation Loss Improved (inf ---> 0.07287040933390422)
# Model Saved
# 100%|██████████| 17/17 [01:32<00:00,  5.45s/it, Epoch=2, LR=9.89e-5, Train_Loss=0.0316]
# 100%|██████████| 3/3 [00:07<00:00,  2.45s/it, Epoch=2, LR=9.89e-5, Valid_Loss=0.0622]
# Validation Loss Improved (0.07287040933390422 ---> 0.06223900525046767)
# Model Saved
# 100%|██████████| 17/17 [01:33<00:00,  5.50s/it, Epoch=3, LR=9.75e-5, Train_Loss=0.023]
# 100%|██████████| 3/3 [00:07<00:00,  2.44s/it, Epoch=3, LR=9.75e-5, Valid_Loss=0.0611]
# Validation Loss Improved (0.06223900525046767 ---> 0.06106808374253966)
# Model Saved
#
# Training complete in 0h 5m 9s
# Best Loss: 0.0611
# VBox(children=(Label(value='0.007 MB of 0.007 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train Loss</td><td>█▁▁</td></tr><tr><td>Valid Loss</td><td>█▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Best Loss</td><td>0.06107</td></tr><tr><td>Train Loss</td><td>0.02302</td></tr><tr><td>Valid Loss</td><td>0.06107</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">g2sx1gpqda82-fold-2</strong> at: <a href='https://wandb.ai/kayfake/Jigsaw/runs/z0sr38yr' target="_blank">https://wandb.ai/kayfake/Jigsaw/runs/z0sr38yr</a><br/> View project at: <a href='https://wandb.ai/kayfake/Jigsaw' target="_blank">https://wandb.ai/kayfake/Jigsaw</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240424_234125-z0sr38yr/logs</code>
# ====== Fold: 3 ======
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01111246169441276, max=1.0)…
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/narotam21477/Precily/lux_nlp/Model_1/wandb/run-20240424_234648-6bwm1lcl</code>
# Syncing run <strong><a href='https://wandb.ai/kayfake/Jigsaw/runs/6bwm1lcl' target="_blank">g2sx1gpqda82-fold-3</a></strong> to <a href='https://wandb.ai/kayfake/Jigsaw' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/kayfake/Jigsaw' target="_blank">https://wandb.ai/kayfake/Jigsaw</a>
#  View run at <a href='https://wandb.ai/kayfake/Jigsaw/runs/6bwm1lcl' target="_blank">https://wandb.ai/kayfake/Jigsaw/runs/6bwm1lcl</a>
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [INFO] Using GPU: NVIDIA RTX A6000
# 100%|██████████| 17/17 [01:33<00:00,  5.48s/it, Epoch=1, LR=9.97e-5, Train_Loss=0.201]
# 100%|██████████| 3/3 [00:07<00:00,  2.43s/it, Epoch=1, LR=9.97e-5, Valid_Loss=0.0416]
# Validation Loss Improved (inf ---> 0.04160145411024923)
# Model Saved
# 100%|██████████| 17/17 [01:32<00:00,  5.45s/it, Epoch=2, LR=9.89e-5, Train_Loss=0.0533]
# 100%|██████████| 3/3 [00:07<00:00,  2.39s/it, Epoch=2, LR=9.89e-5, Valid_Loss=0.0387]
# Validation Loss Improved (0.04160145411024923 ---> 0.03874416368595068)
# Model Saved
# 100%|██████████| 17/17 [01:33<00:00,  5.47s/it, Epoch=3, LR=9.75e-5, Train_Loss=0.0242]
# 100%|██████████| 3/3 [00:07<00:00,  2.41s/it, Epoch=3, LR=9.75e-5, Valid_Loss=0.0214]
# Validation Loss Improved (0.03874416368595068 ---> 0.021390170290850212)
# Model Saved
#
# Training complete in 0h 5m 9s
# Best Loss: 0.0214
# VBox(children=(Label(value='0.007 MB of 0.007 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train Loss</td><td>█▂▁</td></tr><tr><td>Valid Loss</td><td>█▇▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Best Loss</td><td>0.02139</td></tr><tr><td>Train Loss</td><td>0.02424</td></tr><tr><td>Valid Loss</td><td>0.02139</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">g2sx1gpqda82-fold-3</strong> at: <a href='https://wandb.ai/kayfake/Jigsaw/runs/6bwm1lcl' target="_blank">https://wandb.ai/kayfake/Jigsaw/runs/6bwm1lcl</a><br/> View project at: <a href='https://wandb.ai/kayfake/Jigsaw' target="_blank">https://wandb.ai/kayfake/Jigsaw</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240424_234648-6bwm1lcl/logs</code>
# ====== Fold: 4 ======
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011112534585926268, max=1.0…
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/narotam21477/Precily/lux_nlp/Model_1/wandb/run-20240424_235212-0j7s3021</code>
# Syncing run <strong><a href='https://wandb.ai/kayfake/Jigsaw/runs/0j7s3021' target="_blank">g2sx1gpqda82-fold-4</a></strong> to <a href='https://wandb.ai/kayfake/Jigsaw' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/kayfake/Jigsaw' target="_blank">https://wandb.ai/kayfake/Jigsaw</a>
#  View run at <a href='https://wandb.ai/kayfake/Jigsaw/runs/0j7s3021' target="_blank">https://wandb.ai/kayfake/Jigsaw/runs/0j7s3021</a>
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [INFO] Using GPU: NVIDIA RTX A6000
# 100%|██████████| 17/17 [01:33<00:00,  5.48s/it, Epoch=1, LR=9.97e-5, Train_Loss=0.182]
# 100%|██████████| 3/3 [00:07<00:00,  2.44s/it, Epoch=1, LR=9.97e-5, Valid_Loss=0.0396]
# Validation Loss Improved (inf ---> 0.03964367811230646)
# Model Saved
# 100%|██████████| 17/17 [01:24<00:00,  4.95s/it, Epoch=2, LR=9.89e-5, Train_Loss=0.0601]
# 100%|██████████| 3/3 [00:07<00:00,  2.59s/it, Epoch=2, LR=9.89e-5, Valid_Loss=0.0383]
# Validation Loss Improved (0.03964367811230646 ---> 0.03832597448827996)
# Model Saved
# 100%|██████████| 17/17 [01:35<00:00,  5.61s/it, Epoch=3, LR=9.75e-5, Train_Loss=0.0418]
# 100%|██████████| 3/3 [00:07<00:00,  2.41s/it, Epoch=3, LR=9.75e-5, Valid_Loss=0.0594]
# Training complete in 0h 5m 2s
# Best Loss: 0.0383
# VBox(children=(Label(value='0.007 MB of 0.007 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train Loss</td><td>█▂▁</td></tr><tr><td>Valid Loss</td><td>▁▁█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Best Loss</td><td>0.03833</td></tr><tr><td>Train Loss</td><td>0.04181</td></tr><tr><td>Valid Loss</td><td>0.0594</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">g2sx1gpqda82-fold-4</strong> at: <a href='https://wandb.ai/kayfake/Jigsaw/runs/0j7s3021' target="_blank">https://wandb.ai/kayfake/Jigsaw/runs/0j7s3021</a><br/> View project at: <a href='https://wandb.ai/kayfake/Jigsaw' target="_blank">https://wandb.ai/kayfake/Jigsaw</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240424_235212-0j7s3021/logs</code>

# %% [markdown]
# # <span><h1 style = "font-family: garamond; font-size: 40px; font-style: normal; letter-spcaing: 3px; background-color: #f6f5f5; color :#fe346e; border-radius: 100px 100px; text-align:center">Visualizations</h1></span>
#
# <span style="color: #000508; font-family: Segoe UI; font-size: 1.5em; font-weight: 300;"><a href="https://wandb.ai/dchanda/Jigsaw">View the Complete Dashboard Here ⮕</a></span>

# %%
test.dropna(inplace=True)

# %%
@torch.no_grad()
def valid_fn(model, dataloader, device):
    model.eval()
    
    dataset_size = 0
    running_loss = 0.0
    
    PREDS = []
    
    bar = tqdm(enumerate(dataloader), total=len(dataloader))
    for step, data in bar:
        ids = data['text_ids'].to(device, dtype = torch.long)
        mask = data['text_mask'].to(device, dtype = torch.long)
        
        outputs = model(ids, mask)
        sig=nn.Sigmoid()
        outputs=sig(outputs)
        # outputs = outputs.argmax(dim=1)
#         print(len(outputs))
#         print(len(np.max(outputs.cpu().detach().numpy(),axis=1)))
        PREDS.append(outputs.detach().cpu().numpy()) 
        # print(outputs.detach().cpu().numpy())
    
    PREDS = np.concatenate(PREDS)
    gc.collect()
    
    return PREDS

# %%
def inference(model_paths, dataloader, device):
    final_preds = []
    for i, path in enumerate(model_paths):
        model = JigsawModel('roberta-base')
        model.to(CONFIG['device'])
        model.load_state_dict(torch.load(path))
        
        print(f"Getting predictions for model {i+1}")
        preds = valid_fn(model, dataloader, device)
        final_preds.append(preds)
    
    final_preds = np.array(final_preds)
    # print(final_preds)
    final_preds = np.mean(final_preds, axis=0)
    # print(final_preds)
    final_preds[final_preds>=0.5] = 1
    final_preds[final_preds<0.5] = 0
    # final_preds= np.argmax(final_preds,axis=1)
    return final_preds

# %%
class JigsawDatasetTest(Dataset):
    def __init__(self, df, tokenizer, max_length):
        self.df = df
        self.max_len = max_length
        self.tokenizer = tokenizer
        self.text = df['text'].values
        
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, index):
        text = self.text[index]
        inputs = self.tokenizer.encode_plus(
                                text,
                                truncation=True,
                                add_special_tokens=True,
                                max_length=self.max_len,
                                padding='max_length'
                            )
       
        
        ids = inputs['input_ids']
        mask = inputs['attention_mask']
        
       
        
        
        return {
            'text_ids': torch.tensor(ids, dtype=torch.long),
            'text_mask': torch.tensor(mask, dtype=torch.long),
           
        }

# %%
test_sarc=test[['tweet']]
test_sarc['label']=1
test_not_sarc=test[['rephrase']]
test_not_sarc['label']=0

# %%
test_not_sarc.rename(columns={'rephrase': 'text'}, inplace=True)

# %%
test_sarc.rename(columns={'tweet': 'text'}, inplace=True)

# %%
test_final=pd.concat([test_not_sarc,test_sarc])

# %%
test_final
# Out:
#                                                   text  label
# 740  People are more likely to be injured when they...      0
# 645  The side effects of antidepressants can be con...      0
# 733  I hate using the UoM student system because it...      0
# 556  I don't believe that this happens to everyone,...      0
# 827                        dang, America sucks, right?      0
# ..                                                 ...    ...
# 106  @DonaldJTrumpJr If only he had a press Corp in...      1
# 270  @ThomasCabaret84 @MicrobiomDigest @raoult_didi...      1
# 860  do people with clear skin feel accomplished?? ...      1
# 435  @MailOnline Another misogynistic, homophobic r...      1
# 102  Do the #Hokies really have to play 5 against 6...      1
#
# [348 rows x 2 columns]

# %%
test_dataset = JigsawDatasetTest(test_final, tokenizer=CONFIG["tokenizer"], max_length=CONFIG['max_length'])
test_loader = DataLoader(test_dataset, batch_size=CONFIG['valid_batch_size'], 
                              num_workers=2, shuffle=False, pin_memory=True)

# %%
MODEL_PATH_2=['/content/drive/MyDrive/ISarcasm/TaskC_models/roberta_model_EN/Loss-Fold-0.bin','/content/drive/MyDrive/ISarcasm/TaskC_models/roberta_model_EN/Loss-Fold-1.bin','/content/drive/MyDrive/ISarcasm/TaskC_models/roberta_model_EN/Loss-Fold-2.bin','/content/drive/MyDrive/ISarcasm/TaskC_models/roberta_model_EN/Loss-Fold-3.bin','/content/drive/MyDrive/ISarcasm/TaskC_models/roberta_model_EN/Loss-Fold-4.bin']
# MODEL_PATH_2=['/content/drive/MyDrive/ISarcasm/Models_Task_B/bert_tweet_kim_cnn/Loss-Fold-0.bin']
preds = inference(MODEL_PATH_2, test_loader, CONFIG['device'])
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Getting predictions for model 1
# 100%|██████████| 6/6 [00:00<00:00,  8.15it/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Getting predictions for model 2
# 100%|██████████| 6/6 [00:00<00:00,  8.20it/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Getting predictions for model 3
# 100%|██████████| 6/6 [00:00<00:00,  8.15it/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Getting predictions for model 4
# 100%|██████████| 6/6 [00:00<00:00,  8.55it/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Getting predictions for model 5
# 100%|██████████| 6/6 [00:00<00:00,  8.48it/s]

# %%
from sklearn.metrics import jaccard_score,f1_score,accuracy_score,recall_score,precision_score,classification_report
def print_statistics(y, y_pred):
    accuracy = accuracy_score(y, y_pred)
    precision =precision_score(y, y_pred, average='weighted')
    recall = recall_score(y, y_pred, average='weighted')
    f_score = f1_score(y, y_pred, average='weighted')
    print('Accuracy: %.3f\nPrecision: %.3f\nRecall: %.3f\nF_score: %.3f\n'
          % (accuracy, precision, recall, f_score))
    print(classification_report(y, y_pred))
    return accuracy, precision, recall, f_score

# %%
print(print_statistics(test_final['label'],preds))
# Out:
# Accuracy: 0.741
# Precision: 0.819
# Recall: 0.741
# F_score: 0.725
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.49      0.66       174
#            1       0.66      0.99      0.79       174
#
#     accuracy                           0.74       348
#    macro avg       0.82      0.74      0.72       348
# weighted avg       0.82      0.74      0.72       348
#
# (0.7413793103448276, 0.8194055944055944, 0.7413793103448276, 0.7245576388644597)

# %% [markdown]
# ![](https://i.imgur.com/TSIUdfS.jpg)

# %% [markdown]
# ![Upvote!](https://img.shields.io/badge/Upvote-If%20you%20like%20my%20work-07b3c8?style=for-the-badge&logo=kaggle)

# %%
df = pd.read_csv("train.En.csv")
df=df.loc[df['sarcastic'] == 1]
df=df[['tweet','rephrase','sarcastic']]
